# %%
# %load_ext autoreload
# %autoreload 2
from __future__ import absolute_import

# %%
from process_points import *
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# C:\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
# ...

# %%
for trial in finbeats:
    print(finbeats[trial]['trial_name'])
    print(finbeats[trial]['fb_data'])
# Out:
# BTrout2S14a
#     time type       ypos
# 0  0.042    P  15.445399
# 1  0.199    T  14.046151
# 2  0.394    P  15.658472
# 3  0.614    T  14.192599
# 4  0.769    P  15.518749
# 5  0.986    T  14.213454
# 6  1.136    P  15.746927
# 7  1.359    T  14.338486
# Bass1S11
#      time type       ypos
# 0   0.128    P  10.723861
# 1   0.271    T   8.815162
# 2   0.408    P  10.805666
# 3   0.553    T   9.076369
# 4   0.691    P  10.904541
# 5   0.837    T   9.191058
# 6   0.971    P  11.056232
# 7   1.108    T   9.227194
# 8   1.242    P  11.084822
# 9   1.384    T   9.251003
# 10  1.505    P  11.073577
# 11  1.646    T   9.083712
# 12  1.781    P  11.115787
# Bass1S08
#      time type       ypos
# 0   0.103    T  11.518354
# 1   0.214    P  13.097721
# 2   0.347    T  11.242833
# 3   0.460    P  13.083534
# 4   0.570    T  11.012181
# 5   0.709    P  13.466535
# 6   0.838    T  11.367197
# 7   0.944    P  13.019032
# 8   1.040    T  11.053337
# 9   1.166    P  13.325516
# ...
